# %%
import pickle
from matplotlib import pyplot as plt
import numpy as np
import math

# %%
filepath = 'C:/Users/ameld/vnc-ros/workspace/src/intermittent_monitoring/results/'

# %%
#decay rates
{'1': 0.020, '2': 0.010, '3': 0.005}

#changing decay rates
# Out:
# {'1': 0.02, '2': 0.01, '3': 0.005}

# %%
#Random decision results
areas = [1, 2, 3]
robots = [0]
filename = 'random_stats.pkl'
with open(filepath + filename, 'rb') as f:
    random_results = pickle.load(f)
start, ndata = 100, 1000
#Plot of F-measure of areas
colors = ['red', 'blue', 'green']
for i in range(len(areas)):
    area = areas[i]
    print("Area: {}. Average fmeasure: {}. SD: {}".format(area, np.mean(np.array(random_results['fmeasures'][area][start:ndata])), math.sqrt(np.var(np.array(random_results['fmeasures'][area][start:ndata])))))
    plt.plot(random_results['fmeasures'][area][start:ndata], color=colors[i], label="Area " + str(area))
plt.xlabel("Time")
plt.ylabel("F-measure")
plt.title("F-measure of Areas under Random Decision Making")
plt.legend(loc='best')
plt.show()
# Out:
# Area: 1. Average fmeasure: 60.48924530982971. SD: 23.49773323713597
# Area: 2. Average fmeasure: 70.24054565164778. SD: 21.666775158708443
# Area: 3. Average fmeasure: 76.97222158220079. SD: 16.621088253765084

# %%
#Tree-based decision results
areas = [1, 2, 3]
robots = [0]
filename = 'treebased_d1_stats.pkl'
with open(filepath + filename, 'rb') as f:
    tree_d1_results = pickle.load(f)
results = tree_d1_results.copy()
start, ndata = 100, 1000

#Plot of F-measure of areas
colors = ['red', 'blue', 'green']
for i in range(len(areas)):
    area = areas[i]
    print("Area: {}. Average fmeasure: {}. SD: {}".format(area, np.mean(np.array(results['fmeasures'][area][start:ndata])), math.sqrt(np.var(np.array(results['fmeasures'][area][start:ndata])))))
    plt.plot(results['fmeasures'][area][start:ndata], color=colors[i], label="Area " + str(area))
plt.xlabel("Time")
plt.ylabel("F-measure")
plt.title("F-measure of Areas under Tree-based Decision Making, d=1")
plt.legend(loc='best')
plt.show()
# Out:
# Area: 1. Average fmeasure: 71.75028804355198. SD: 16.68965791534172
# Area: 2. Average fmeasure: 66.17330138524373. SD: 19.01343039407879
# Area: 3. Average fmeasure: 54.82326182047526. SD: 22.471879568821368

# %%
#Tree-based decision results
areas = [1, 2, 3]
robots = [0]
filename = 'treebased_d4_stats.pkl'
with open(filepath + filename, 'rb') as f:
    tree_d4_results = pickle.load(f)
results = tree_d4_results.copy()
start, ndata = 100, 1000

#Plot of F-measure of areas
colors = ['red', 'blue', 'green']
for i in range(len(areas)):
    area = areas[i]
    print("Area: {}. Average fmeasure: {}. SD: {}".format(area, np.mean(np.array(results['fmeasures'][area][start:ndata])), math.sqrt(np.var(np.array(results['fmeasures'][area][start:ndata])))))
    plt.plot(results['fmeasures'][area][start:ndata], color=colors[i], label="Area " + str(area))
plt.xlabel("Time")
plt.ylabel("F-measure")
plt.title("F-measure of Areas under Tree-based Decision Making, d=4")
plt.legend(loc='best')
plt.show()
# Out:
# Area: 1. Average fmeasure: 72.58923650953504. SD: 16.733315491754986
# Area: 2. Average fmeasure: 72.43788362714979. SD: 17.264372491855106
# Area: 3. Average fmeasure: 69.19621963924831. SD: 18.59805744481271

# %%
#Tree-based decision results
areas = [1, 2, 3]
robots = [0]
filename = 'treebased_d6_stats.pkl'
with open(filepath + filename, 'rb') as f:
    tree_d6_results = pickle.load(f)
    
results = tree_d6_results.copy()
start, ndata = 100, 1000

#Plot of F-measure of areas
colors = ['red', 'blue', 'green']
for i in range(len(areas)):
    area = areas[i]
    print("Area: {}. Average fmeasure: {}. SD: {}".format(area, np.mean(np.array(results['fmeasures'][area][start:ndata])), math.sqrt(np.var(np.array(results['fmeasures'][area][start:ndata])))))
    plt.plot(results['fmeasures'][area][start:ndata], color=colors[i], label="Area " + str(area))
plt.xlabel("Time")
plt.ylabel("F-measure")
plt.title("F-measure of Areas under Tree-based Decision Making, d=6")
plt.legend(loc='best')
plt.show()
# Out:
# Area: 1. Average fmeasure: 71.75476176791722. SD: 17.416693254287527
# Area: 2. Average fmeasure: 74.38760011461046. SD: 14.936757970166633
# Area: 3. Average fmeasure: 64.78151782989502. SD: 17.81853154775241

# %%
#Tree-based decision results
areas = [1, 2, 3]
robots = [0]
filename = 'treebased_d10_stats.pkl'
with open(filepath + filename, 'rb') as f:
    results = pickle.load(f)
start, ndata = 100, 1000
#Plot of F-measure of areas
colors = ['red', 'blue', 'green']
for i in range(len(areas)):
    area = areas[i]
    print("Area: {}. Average fmeasure: {}. SD: {}".format(area, np.mean(np.array(results['fmeasures'][area][start:ndata])), math.sqrt(np.var(np.array(results['fmeasures'][area][start:ndata])))))
    plt.plot(results['fmeasures'][area][start:ndata], color=colors[i], label="Area " + str(area))
plt.xlabel("Time")
plt.ylabel("F-measure")
plt.title("F-measure of Areas under Tree-based Decision Making, d=10")
plt.legend(loc='best')
plt.show()
# Out:
# Area: 1. Average fmeasure: 24.16287653289845. SD: 31.898018034022815
# Area: 2. Average fmeasure: 28.190881433255143. SD: 32.59967590768609
# Area: 3. Average fmeasure: 35.00858921315935. SD: 28.38055693153535

# %% [markdown]
# Takes time to generate/process results. By the time the robot has made a decision, the F-measures have already gone low.

# %% [markdown]
# ### Integer programming

# %%
def decay(rate, t, starting_value):
    """
    Decay function
    :param rate:
    :param t:
    :return:
    """
    decayed_fmeasure = starting_value*(1.0 - rate)**t
    return decayed_fmeasure

# %%
def get_time_given_decay(max_fmeasure, decayed_fmeasure, rate):
    """
    Retrieves time given decayed measure and decay rate (by inversion)
    :param decayed_measure:
    :param rate:
    :return:
    """
    t = math.log((decayed_fmeasure/max_fmeasure), 1.0-rate)

    return t

# %%
def beta_rate(rate, rates):
    """
    Computes the normalized F-measure decay rate, which then is the Loss growth rate
    :param rate (float): decay rate
    :param rates (list): list of decay rates
    :return:
    """
    beta = rate / sum(rates)
    return beta

# %%
def compute_loss(max_fmeasure, decayed_fmeasure, fsafe, rate, rates, est_duration):
    """
    Computes loss by estimating the decayed fmeasure given the decay rate after a set duration
    :param decayed_fmeasure:
    :param rate:
    :param duration:
    :return:
    """
    t0 = get_time_given_decay(max_fmeasure, decayed_fmeasure, rate)
    t = t0 + est_duration
    est_decayed_fmeasure = decay(rate, t, max_fmeasure)
    print("Current measure: {}. Estimated decayed measure: {}".format(decayed_fmeasure, est_decayed_fmeasure))

    if est_decayed_fmeasure < fsafe:
        diff = fsafe - est_decayed_fmeasure
    else:
        diff = 0

    beta = beta_rate(rate, rates)

    loss = beta*diff**2

    return float(loss)

# %%
def compute_duration(distance, velocity, max_measure, curr_measure, restoration):
    """
    Computes duration of a mission to an area, which includes time to travel to the area given velocity, plus restoration 
    (whether to charge up battery or restore F-measure)
    """
    duration_travel = distance/velocity
    duration_restoration = restoration*(max_measure - curr_measure)
    duration = duration_travel + duration_restoration
    return duration

# %% [markdown]
# To get:
# 1. Current time for each area
# 2. Average decision step for each area
# 3. Loss for each area
#
# After these, we then set up the integer programming.
# 1. The constants
# 2. The decision variables
# 3. The objective function
# 4. The constraints
# 5. We then get the solution of the IP, and convert it into area format for our code/program

# %%
decay_rates = {'1': 0.020, '2': 0.010, '3': 0.005}

# %%
dist_matrix = np.array([[0, 10, 18, 15],
                       [10, 0, 15, 18],
                       [18, 15, 0, 10],
                       [15, 18, 10, 0]])

# %%
#Average distance to a node
ave_dist2_node = np.mean(dist_matrix, axis=0)
ave_dist2_node
# Out:
# array([10.75, 10.75, 10.75, 10.75])

# %%
current_fmeasure = {'1': 100, '2': 80, '3': 65}

# %%
max_fmeasure = 100
curr_time = list()
areas = list(decay_rates.keys())

for i in range(len(areas)):
    area = areas[i]
    curr_time.append(get_time_given_decay(current_fmeasure[area], max_fmeasure, decay_rates[area]))
    
curr_time
# Out:
# [-0.0, -22.202596467108954, -85.9410118174046]

# %%
duration_list = list()

# %%
velocity = 1
restore_t = 0.10 #restoration time
fsafe = 80
list_decay_rates = list(decay_rates.values())

# %%
battery = 5
batt_cons_travel_unit_t = 0.10
batt_cons_restore_unit_t = 0.10

#Average battery consumption = average distance + average restoration
ave_travel_consume = (np.mean(dist_matrix) / velocity) * batt_cons_travel_unit_t
ave_restoration = restore_t * (max_fmeasure/2) * batt_cons_restore_unit_t
ave_feasible_batt_consumption = 2*ave_travel_consume + ave_restoration
print("Mean travel consumption: {}. Feasible batt consumption: {}.".format(ave_travel_consume, ave_feasible_batt_consumption))

k = 3
dec_steps = min(k, int(battery // ave_feasible_batt_consumption), len(areas)) #Feasible decision steps
print("Dec steps:", dec_steps)
# Out:
# Mean travel consumption: 1.075. Feasible batt consumption: 2.65.
# Dec steps: 1

# %% [markdown]
# A potential implementation here is that if the length of the output is less than k, then we know that the robot has to go back to the charging station.
#
# Another remark: We assume our foresight of decision steps is that we get to visit each area at most once. And so, the max decision steps we foresee is the number of areas to monitor. While, the min decision steps would be the number of feasible areas.

# %% [markdown]
# #### Set up the Integer Programming problem

# %%
import gurobipy as gp
from gurobipy import *

# %%
# solution = list() #container for optimal decision
# charging_station = 0

# #If there is a feasible decision step, we find optimal decision
# if dec_steps > 0:
#     #Approximate loss per area across decision steps
#     losses = list()
#     for i in range(len(areas)):
#         losses.append([])

#     for i in range(len(areas)):
#         area = areas[i]
#         print("\nArea:", area)
#         for dec_step in range(dec_steps):
#             distance = (dec_step+1)*ave_dist2_node[int(area)-1]
#             duration = compute_duration(distance, velocity, max_fmeasure, current_fmeasure[area], restore_t)
#             loss = compute_loss(max_fmeasure, current_fmeasure[area], fsafe, decay_rates[area], list_decay_rates, duration)
#             print("Dec. step: {}. Distance: {}. Duration: {}. Loss: {}.".format(dec_step+1, distance, duration, loss))
#             losses[i].append(loss)

#     losses = np.array(losses)

#     #Set up the IP model
#     m = gp.Model()
    
#     ##Decision variables
#     decision_vars = list()
#     for i in range(len(areas)):
#         decision_vars.append([])
        
#     for i in range(len(areas)):
#         for d in range(dec_steps):
#             decision_vars[i].append(m.addVar(vtype=GRB.INTEGER, name='a' + str(areas[i]) + 'd' + str(d)))
            
#     decision_vars = np.array(decision_vars)
    
#     #Objective function
#     objective = np.sum(losses*decision_vars)
#     m.setObjective(objective, GRB.MINIMIZE)
    
#     #Constraints
#     ##For each area, we can visit that at most once
#     for i in range(len(areas)):
#         m.addConstr(0 <= np.sum(decision_vars, axis=1)[i])
#         m.addConstr(np.sum(decision_vars, axis=1)[i] <= 1)

#     ##For each decision step, there should be only one area assignment
#     for d in range(dec_steps):
#         m.addConstr(np.sum(decision_vars, axis=0)[d] == 1)
        
#     ##All decision assignments should equal to the number of decision steps, 
#     ## i.e., at each decision step we have one assignment
#     m.addConstr(np.sum(decision_vars) == dec_steps)

#     ##Each area can be assigned or not at a given decision step, i.e., its value is either 0 or 1
#     for i in range(len(areas)):
#         for d in range(dec_steps):
#             m.addRange(decision_vars[i][d], 0, 1)

#     #Optimize the model
#     m.optimize()

#     #Print out the result
#     #Retrieve the result
#     result = np.zeros(shape=decision_vars.shape)
#     for i in range(len(areas)):
#         for d in range(dec_steps):
#             print(decision_vars[i][d])
#             result[i][d] = int(decision_vars[i][d].X)
            
#     print("Result:", result)
            
#     #We retrieve the optimal decision: monitor an area
#     for step in range(dec_steps):
#         print("Result:", result[:, step], np.where(result[:, step] == 1), np.where(result[:, step] == 1)[0][0])
#         opt_area = np.where(result[:, step] == 1)[0][0]
#         solution.append(opt_area + 1) #adjust area index: +1
# #     ##If feasible decision steps is less than total areas, we go back to the charging station after the last feasible area
# #     ##Hmm...could be. 
# #     ##It could also be we make a next decision once again. After we reach at the end. Shouldn't it be?
# #     if dec_steps < k:
# #         solution.append(charging_station)

# #Else: there is no more feasible decision, we go back to the charging station.
# else:
#     #We go back to the charging station
#     solution.append(charging_station)
    
# print("Solution:", solution)

# %% [markdown]
# #A function that extracts the area that has value = 1 for a decision step
# #How about when to charge? We charge if k < dec_steps. Note, k is the desired decision steps. But if the feasible dec_steps is  less than k, then we know that we have to charge somewhere.
# #Thus, a potential solution: We iterate through k. If not None, we get the area whose value is 1; (note, that we are assured that there will be an assignment as we enforced as our constraint). If None, then we go back to the charging station. Then from the charging station, we call the function once again.

# %% [markdown]
# Next up: What up the charging station? We may need to come up with a solution.
# If we now take into account battery, the determination of decision steps takes into place. We now have feasibility in the picture.

# %%
#Tree-based decision results
areas = [1, 2, 3]
robots = [0]
filename = 'treebased_d3_stats.pkl'
with open(filepath + filename, 'rb') as f:
    tree_d3_results = pickle.load(f)

results = tree_d3_results.copy()
start, ndata = 100, 2000

#Plot of F-measure of areas
colors = ['red', 'blue', 'green']
for i in range(len(areas)):
    area = areas[i]
    print("Area: {}. Average fmeasure: {}. SD: {}".format(area, np.mean(np.array(results['fmeasures'][area][start:ndata])), math.sqrt(np.var(np.array(results['fmeasures'][area][start:ndata])))))
    plt.plot(results['fmeasures'][area][start:ndata], color=colors[i], label="Area " + str(area))
plt.xlabel("Time")
plt.ylabel("F-measure")
plt.title("F-measure of Areas under Tree-based Decision Making, d=3")
plt.legend(loc='best')
plt.show()
# Out:
# Area: 1. Average fmeasure: 70.7042618500559. SD: 17.582912400366524
# Area: 2. Average fmeasure: 72.1989672088623. SD: 15.857898490388246
# Area: 3. Average fmeasure: 72.0824461957028. SD: 15.216240306971299

# %%
#Integer programming decision results
areas = [1, 2, 3]
robots = [0]
filename = 'intprogram_d3_stats.pkl'
with open(filepath + filename, 'rb') as f:
    intprog_d3_results = pickle.load(f)
start, ndata = 100, 2000

results = intprog_d3_results.copy()
#Plot of F-measure of areas
colors = ['red', 'blue', 'green']
for i in range(len(areas)):
    area = areas[i]
    print("Area: {}. Average fmeasure: {}. SD: {}".format(area, np.mean(np.array(results['fmeasures'][area][start:ndata])), math.sqrt(np.var(np.array(results['fmeasures'][area][start:ndata])))))
    plt.plot(results['fmeasures'][area][start:ndata], color=colors[i], label="Area " + str(area))
plt.xlabel("Time")
plt.ylabel("F-measure")
plt.title("F-measure of Areas under Integer Programming Decision Making, d=3")
plt.legend(loc='best')
plt.show()
# Out:
# Area: 1. Average fmeasure: 57.25744101475728. SD: 23.079687080233544
# Area: 2. Average fmeasure: 74.20053585855584. SD: 14.833022967482682
# Area: 3. Average fmeasure: 86.0041810768529. SD: 8.484251338475154

# %% [markdown]
# Remarks:
# 1. Need to re-consider the loss function.
# 2. Record the computed cost and actual cost

# %% [markdown]
# ### Cost computation

# %%
def convert_fmeasures_result2dict(pickled_fmeasures_result):
    """
    Converts the pickled result ADT into a 
    """
    areas = list(pickled_fmeasures_result.keys())
    length = len(pickled_fmeasures_result[areas[0]])
    
    converted_result = list() #Container of F-measure of areas for each timestep
    for i in range(length):
        d = dict()
        for area in areas:
            d[str(area)] = pickled_fmeasures_result[area][i]
        converted_result.append(d)
    return converted_result

# %%
def compute_cost_fmeasures(fmeasures, decay_rates, fmax, fsafe):
    """
    Computes the cost, (i.e., the sum of losses), given the F-measures
    :param fmeasures: dict of F-measures of areas
    :param decay_rates: dict of decay rates of areas
    :return:
    """
    areas = fmeasures.keys()
    
    computed_cost = 0
    for area in areas:
        if fmeasures[area] < fsafe:
            diff = fsafe - fmeasures[area]
        else:
            diff = 0

        beta = beta_rate(decay_rates[area], list(decay_rates.values()))
        loss = beta*diff**2
        computed_cost += loss

    actual_cost = 0
    for area in areas:
        actual_diff = fmax - fmeasures[area]
        actual_cost += actual_diff
        
    return actual_cost, computed_cost

# %%
def compute_cost_fmeasures(fmeasures, fmax, fsafe, fcrit):
    """
    Computes the cost, (i.e., the sum of losses), given the F-measures
    :param fmeasures: dict of F-measures of areas
    :return:
    """
    computed_cost = 0
    areas = fmeasures.keys()
    for area in areas:
        if fmeasures[area] >= fsafe:
            loss = 0
        elif fcrit <= fmeasures[area] and fmeasures[area] < fsafe:
            loss = fsafe - fmeasures[area]
        elif fmeasures[area] < fcrit:
            loss = (fsafe - fmeasures[area])**2
        computed_cost += loss
    
    actual_cost = 0
    for area in areas:
        actual_diff = fmax - fmeasures[area]
        actual_cost += actual_diff
        
    return actual_cost, computed_cost

# %%
def cost_history(converted_fmeasures_result, fmax, fsafe, fcrit):
    """
    Computes and compiles the cost throughout the history of operation
    Input:
        converted_fmeasures_result: (list) - list of fmeasures of areas for each t
    """
    computed_costs = list()
    actual_costs = list()
    total_computed_cost = 0
    total_actual_cost = 0
    for i in range(len(converted_fmeasures_result)):
        fmeasures = converted_fmeasures_result[i]
        cost = compute_cost_fmeasures(fmeasures, fmax, fsafe, fcrit)
        total_actual_cost += cost[0] #Actual cost
        actual_costs.append(cost[0])
        total_computed_cost += cost[1] #Computed cost
        computed_costs.append(cost[1])
#     print("Average cost: {}. SD: {}".format(np.mean(np.array(costs)), math.sqrt(np.var(np.array(costs)))))
#     print("Total cost:", total_cost)

    costs_dict = dict()
    costs_dict['actual'] = (total_actual_cost, actual_costs)
    costs_dict['computed'] = (total_computed_cost, computed_costs)
    return costs_dict

# %%
random_cost_history = cost_history(convert_fmeasures_result2dict(random_results['fmeasures']), fmax=100, fsafe=80, fcrit=50)

# %%
tree_d1_cost_history = cost_history(convert_fmeasures_result2dict(tree_d1_results['fmeasures']), fmax=100, fsafe=80, fcrit=50)
tree_d3_cost_history = cost_history(convert_fmeasures_result2dict(tree_d3_results['fmeasures']), fmax=100, fsafe=80, fcrit=50)
tree_d4_cost_history = cost_history(convert_fmeasures_result2dict(tree_d4_results['fmeasures']), fmax=100, fsafe=80, fcrit=50)
tree_d6_cost_history = cost_history(convert_fmeasures_result2dict(tree_d6_results['fmeasures']), fmax=100, fsafe=80, fcrit=50)

# %%
intprog_d3_cost_history = cost_history(convert_fmeasures_result2dict(intprog_d3_results['fmeasures']), fmax=100, fsafe=80, fcrit=50)

# %%
# plt.plot(random_cost_history[1][start:ndata], label = 'Random')
# plt.plot(tree_d1_cost_history[1][start:ndata], label = 'Tree d=1')
plt.plot(tree_d3_cost_history['computed'][1][start:ndata], label = 'Tree d=3')
#plt.plot(tree_d4_cost_history['computed'][1][start:ndata], label = 'Tree d=4')
# plt.plot(tree_d6_cost_history[1][start:ndata], label = 'Tree d=6')
plt.plot(intprog_d3_cost_history['computed'][1][start:ndata], label = 'IntProg d=3', linestyle = 'dotted')
plt.xlabel("Time")
plt.ylabel("Computed cost")
#plt.title("F-measure of Areas under Integer Programming Decision Making, d=3")
plt.legend(loc='best')
plt.show()

# %%
print("Tree-based d=3 average computed cost:", np.mean(tree_d3_cost_history['computed'][1][start:ndata]), math.sqrt(np.var(tree_d3_cost_history['computed'][1][start:ndata])))
print("Integer programming d=3 average computed cost:", np.mean(intprog_d3_cost_history['computed'][1][start:ndata]), math.sqrt(np.var(intprog_d3_cost_history['computed'][1][start:ndata])))
# Out:
# Tree-based d=3 average computed cost: 318.63936759652915 522.4549277300174
# Integer programming d=3 average computed cost: 941.6437148413127 1145.8710255461858

# %%
plt.plot(tree_d3_cost_history['actual'][1][start:ndata], label = 'Tree d=3')
#plt.plot(tree_d4_cost_history['actual'][1][start:ndata], label = 'Tree d=4')
# plt.plot(tree_d6_cost_history[1][start:ndata], label = 'Tree d=6')
plt.plot(intprog_d3_cost_history['actual'][1][start:ndata], label = 'IntProg d=3', linestyle='dotted')
plt.xlabel("Time")
plt.ylabel("Actual cost")
#plt.title("F-measure of Areas under Integer Programming Decision Making, d=3")
plt.legend(loc='best')
plt.show()

# %%
print("Tree-based d=3 average actual cost:", np.mean(tree_d3_cost_history['actual'][1][start:ndata]), math.sqrt(np.var(tree_d3_cost_history['actual'][1][start:ndata])))
print("Integer programming d=3 average actual cost:", np.mean(intprog_d3_cost_history['actual'][1][start:ndata]), math.sqrt(np.var(intprog_d3_cost_history['actual'][1][start:ndata])))
# Out:
# Tree-based d=3 average actual cost: 84.84780082066854 18.05261444279003
# Integer programming d=3 average actual cost: 82.73598451611069 21.683746171568412
